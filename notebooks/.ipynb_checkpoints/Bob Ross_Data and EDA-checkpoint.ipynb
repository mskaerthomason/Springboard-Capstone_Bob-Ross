# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.color_palette("muted")
import scipy.stats as stats
# %matplotlib inline

# %%
elements = pd.read_csv('../data/elements-by-episode.csv', index_col='EPISODE')
elements.head()
# Out:
#                          TITLE  APPLE_FRAME  AURORA_BOREALIS  BARN  BEACH  \
# EPISODE
# S01E01   "A WALK IN THE WOODS"            0                0     0      0
# S01E02          "MT. MCKINLEY"            0                0     0      0
# S01E03          "EBONY SUNSET"            0                0     0      0
# S01E04           "WINTER MIST"            0                0     0      0
# S01E05          "QUIET STREAM"            0                0     0      0
#
#          BOAT  BRIDGE  BUILDING  BUSHES  CABIN     ...       TOMB_FRAME  TREE  \
# EPISODE                                            ...
# S01E01      0       0         0       1      0     ...                0     1
# S01E02      0       0         0       0      1     ...                0     1
# S01E03      0       0         0       0      1     ...                0     1
# S01E04      0       0         0       1      0     ...                0     1
# S01E05      0       0         0       0      0     ...                0     1
#
#          TREES  TRIPLE_FRAME  WATERFALL  WAVES  WINDMILL  WINDOW_FRAME  \
# EPISODE
# S01E01       1             0          0      0         0             0
# S01E02       1             0          0      0         0             0
# S01E03       1             0          0      0         0             0
# S01E04       1             0          0      0         0             0
# S01E05       1             0          0      0         0             0
#
#          WINTER  WOOD_FRAMED
# EPISODE
# S01E01        0            0
# S01E02        1            0
# S01E03        1            0
# S01E04        0            0
# S01E05        0            0
#
# [5 rows x 68 columns]

# %%
columns = elements.columns
s = []
for c in columns:
    s.append([c, elements[c][elements[c]==1].size])

# %%
elem_df_extras = pd.DataFrame(s, columns=['element','count'])

# %%
elem_df = elem_df_extras[2:].sort_values('count', ascending=False)
elem_df.head()
# Out:
#       element  count
# 59       TREE    361
# 60      TREES    337
# 17  DECIDUOUS    227
# 15    CONIFER    212
# 14     CLOUDS    179

# %%
fig, ax = plt.subplots(1,1)
sns.barplot(y="element", x="count", data=elem_df, ax=ax)
fig.set_size_inches(5,15)
ax.set_xlabel('Frequency', fontsize=15)
ax.set_ylabel('Element in painting', fontsize=15)

# %% [markdown]
# There are clearly some very low frequency occurances here, including descriptors about frame shape, which are not relevent.

# %%
elem_df_todrop = elem_df[elem_df['count'] < 5]
dropcols = elem_df_todrop['element'].tolist()
dropcols
# Out:
# ['CACTUS',
#  'PORTRAIT',
#  'MOON',
#  'BOAT',
#  'MILL',
#  'CIRCLE_FRAME',
#  'AURORA_BOREALIS',
#  'TOMB_FRAME',
#  'WINDOW_FRAME',
#  'SPLIT_FRAME',
#  'WINDMILL',
#  'TRIPLE_FRAME',
#  'LIGHTHOUSE',
#  'SEASHELL_FRAME',
#  'RECTANGULAR_FRAME',
#  'RECTANGLE_3D_FRAME',
#  'PERSON',
#  'HALF_OVAL_FRAME',
#  'HALF_CIRCLE_FRAME',
#  'FLORIDA_FRAME',
#  'FIRE',
#  'FARM',
#  'DOUBLE_OVAL_FRAME',
#  'DOCK',
#  'DIANE_ANDRE',
#  'BUILDING',
#  'WOOD_FRAMED',
#  'LAKES']

# %% [markdown]
# I also want to make sure we drop ```oval_frame```,  ```steve_ross```, ```guest```, and ```framed``` as categories not relevant to this analysis.

# %%
dropcols.extend(['OVAL_FRAME','STEVE_ROSS','GUEST','FRAMED'])
dropcols
# Out:
# ['CACTUS',
#  'PORTRAIT',
#  'MOON',
#  'BOAT',
#  'MILL',
#  'CIRCLE_FRAME',
#  'AURORA_BOREALIS',
#  'TOMB_FRAME',
#  'WINDOW_FRAME',
#  'SPLIT_FRAME',
#  'WINDMILL',
#  'TRIPLE_FRAME',
#  'LIGHTHOUSE',
#  'SEASHELL_FRAME',
#  'RECTANGULAR_FRAME',
#  'RECTANGLE_3D_FRAME',
#  'PERSON',
#  'HALF_OVAL_FRAME',
#  'HALF_CIRCLE_FRAME',
#  'FLORIDA_FRAME',
#  'FIRE',
#  'FARM',
#  'DOUBLE_OVAL_FRAME',
#  'DOCK',
#  'DIANE_ANDRE',
#  'BUILDING',
#  'WOOD_FRAMED',
#  'LAKES',
#  'OVAL_FRAME',
#  'STEVE_ROSS',
#  'GUEST',
#  'FRAMED']

# %%
elements_new = elements.drop(dropcols, axis=1)
elements_new.head()
# Out:
#                          TITLE  APPLE_FRAME  BARN  BEACH  BRIDGE  BUSHES  \
# EPISODE
# S01E01   "A WALK IN THE WOODS"            0     0      0       0       1
# S01E02          "MT. MCKINLEY"            0     0      0       0       0
# S01E03          "EBONY SUNSET"            0     0      0       0       0
# S01E04           "WINTER MIST"            0     0      0       0       1
# S01E05          "QUIET STREAM"            0     0      0       0       0
#
#          CABIN  CIRRUS  CLIFF  CLOUDS   ...    ROCKS  SNOW  SNOWY_MOUNTAIN  \
# EPISODE                                 ...
# S01E01       0       0      0       0   ...        0     0               0
# S01E02       1       0      0       1   ...        0     1               1
# S01E03       1       0      0       0   ...        0     0               0
# S01E04       0       0      0       1   ...        0     0               1
# S01E05       0       0      0       0   ...        1     0               0
#
#          STRUCTURE  SUN  TREE  TREES  WATERFALL  WAVES  WINTER
# EPISODE
# S01E01           0    0     1      1          0      0       0
# S01E02           0    0     1      1          0      0       1
# S01E03           1    1     1      1          0      0       1
# S01E04           0    0     1      1          0      0       0
# S01E05           0    0     1      1          0      0       0
#
# [5 rows x 36 columns]

# %% [markdown]
# Update the histogram

# %%
new_columns = elements_new.columns
n = []
for c in new_columns:
    n.append([c, elements_new[c][elements_new[c]==1].size])
elem_df_extras = pd.DataFrame(n, columns=['element','count'])
elem_df = elem_df_extras[2:].sort_values('count', ascending=False)

# %%
fig, ax = plt.subplots(1,1)
sns.barplot(y="element", x="count", data=elem_df, ax=ax)
fig.set_size_inches(5,10)
ax.set_xlabel('Frequency', fontsize=15)
ax.set_ylabel('Element in painting', fontsize=15)

# %% [markdown]
# tidy up the cases in column headers and title column.

# %%
elements_new.columns = elements_new.columns.str.lower()

# %%
elements_new['title'] = elements_new['title'].str.lower()

# %%
elements_new['title'] = elements_new['title'].str.replace('"', '')

# %%
elements_new.head()
# Out:
#                        title  apple_frame  barn  beach  bridge  bushes  cabin  \
# EPISODE
# S01E01   a walk in the woods            0     0      0       0       1      0
# S01E02          mt. mckinley            0     0      0       0       0      1
# S01E03          ebony sunset            0     0      0       0       0      1
# S01E04           winter mist            0     0      0       0       1      0
# S01E05          quiet stream            0     0      0       0       0      0
#
#          cirrus  cliff  clouds   ...    rocks  snow  snowy_mountain  \
# EPISODE                          ...
# S01E01        0      0       0   ...        0     0               0
# S01E02        0      0       1   ...        0     1               1
# S01E03        0      0       0   ...        0     0               0
# S01E04        0      0       1   ...        0     0               1
# S01E05        0      0       0   ...        1     0               0
#
#          structure  sun  tree  trees  waterfall  waves  winter
# EPISODE
# S01E01           0    0     1      1          0      0       0
# S01E02           0    0     1      1          0      0       1
# S01E03           1    1     1      1          0      0       1
# S01E04           0    0     1      1          0      0       0
# S01E05           0    0     1      1          0      0       0
#
# [5 rows x 36 columns]

# %% [markdown]
# Export updated data frame

# %%
elements_new.to_csv('../data/elements.csv')
