# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.color_palette("muted")
import scipy.stats as stats
# %matplotlib inline
import scipy.stats as stats
from datetime import datetime as dt
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
elements = pd.read_csv('../data/elements.csv', index_col='title')
stats = pd.read_csv('../data/video_stats2.csv', index_col='episode_title')

# %%
print('the number of items in elements df is', len(elements))
elements.head()
# Out:
# the number of items in elements df is 403
#                     EPISODE  apple_frame  barn  beach  bridge  bushes  cabin  \
# title
# a walk in the woods  S01E01            0     0      0       0       1      0
# mt. mckinley         S01E02            0     0      0       0       0      1
# ebony sunset         S01E03            0     0      0       0       0      1
# winter mist          S01E04            0     0      0       0       1      0
# quiet stream         S01E05            0     0      0       0       0      0
#
#                      cirrus  cliff  clouds  conifer  cumulus  deciduous  \
# title
# a walk in the woods       0      0       0        0        0          1
# mt. mckinley              0      0       1        1        0          0
# ebony sunset              0      0       0        1        0          0
# winter mist               0      0       1        1        0          0
# quiet stream              0      0       0        0        0          1
#
#                      fence  flowers  fog  grass  hills  lake  mountain  \
# title
# a walk in the woods      0        0    0      1      0     0         0
# mt. mckinley             0        0    0      0      0     0         1
# ebony sunset             1        0    0      0      0     0         1
# winter mist              0        0    0      0      0     1         1
# quiet stream             0        0    0      0      0     0         0
#
#                      mountains  night  ocean  palm_trees  path  river  rocks  \
# title
# a walk in the woods          0      0      0           0     0      1      0
# mt. mckinley                 0      0      0           0     0      0      0
# ebony sunset                 1      0      0           0     0      0      0
# winter mist                  0      0      0           0     0      0      0
# quiet stream                 0      0      0           0     0      1      1
#
#                      snow  snowy_mountain  structure  sun  tree  trees  \
# title
# a walk in the woods     0               0          0    0     1      1
# mt. mckinley            1               1          0    0     1      1
# ebony sunset            0               0          1    1     1      1
# winter mist             0               1          0    0     1      1
# quiet stream            0               0          0    0     1      1
#
#                      waterfall  waves  winter
# title
# a walk in the woods          0      0       0
# mt. mckinley                 0      0       1
# ebony sunset                 0      0       1
# winter mist                  0      0       0
# quiet stream                 0      0       0

# %% [markdown]
# The elements dataframe is already shorter than the stats dataframe, but we need to drop the episodes that were made irrelevant from cleaning (infrequent topics, or only hosted by a guest, not Bob Ross).

# %%
droprows = elements[elements.sum(axis=1)==0].index.tolist()
print('there are ', len(droprows),' episodes to drop')
# Out:
# there are  6  episodes to drop

# %%
elements = elements.drop(droprows)

# %%
elements.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397 entries, a walk in the woods to wilderness day
# Data columns (total 36 columns):
# EPISODE           397 non-null object
# apple_frame       397 non-null int64
# barn              397 non-null int64
# beach             397 non-null int64
# bridge            397 non-null int64
# bushes            397 non-null int64
# cabin             397 non-null int64
# cirrus            397 non-null int64
# cliff             397 non-null int64
# clouds            397 non-null int64
# conifer           397 non-null int64
# cumulus           397 non-null int64
# deciduous         397 non-null int64
# fence             397 non-null int64
# flowers           397 non-null int64
# fog               397 non-null int64
# grass             397 non-null int64
# hills             397 non-null int64
# lake              397 non-null int64
# mountain          397 non-null int64
# mountains         397 non-null int64
# night             397 non-null int64
# ocean             397 non-null int64
# palm_trees        397 non-null int64
# path              397 non-null int64
# river             397 non-null int64
# rocks             397 non-null int64
# snow              397 non-null int64
# snowy_mountain    397 non-null int64
# structure         397 non-null int64
# sun               397 non-null int64
# tree              397 non-null int64
# trees             397 non-null int64
# waterfall         397 non-null int64
# waves             397 non-null int64
# winter            397 non-null int64
# dtypes: int64(35), object(1)
# memory usage: 114.8+ KB

# %%
print('the number of items in stats df is', len(stats))
stats.head()
# Out:
# the number of items in stats df is 446
#                                    id  \
# episode_title
# glacier lake              TohG7F8M3Ls
# island in the wilderness  lLWEXRAnQd0
# reflections of calm       kJFB6rH3z2A
# mountain summit           kasGRkfkiPM
# delightful meadow home    tWoInh2USOs
#
#                                                                       title  \
# episode_title
# glacier lake                  Bob Ross - Glacier Lake (Season 28 Episode 6)
# island in the wilderness  Bob Ross - Island in the Wilderness (Season 29...
# reflections of calm       Bob Ross - Reflections of Calm (Season 31 Epis...
# mountain summit           Bob Ross - Mountain Summit (Season 13 Episode 10)
# delightful meadow home    Bob Ross - Delightful Meadow Home (Season 26 E...
#
#                           viewCount  likeCount  favoriteCount  dislikeCount  \
# episode_title
# glacier lake                1160972      14005              0           311
# island in the wilderness    7529170     152477              0          2249
# reflections of calm         1432050      17979              0           334
# mountain summit             3041171      22498              0           542
# delightful meadow home       453935       3930              0            96
#
#                           commentCount  season_num  episode_num
# episode_title
# glacier lake                      1589        28.0          6.0
# island in the wilderness         21209        29.0          1.0
# reflections of calm               2346        31.0          1.0
# mountain summit                   3310        13.0         10.0
# delightful meadow home             457        26.0          2.0

# %% [markdown]
# Join tables, where unmatched records in ```stats``` are dropped.
