# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from datetime import datetime as dt
# %matplotlib inline
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Read json text

# %%
import json

json_data = json.loads(open('../data/video_json.txt').read())
json_data[1]
# Out:
# {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/tAr09q1XjvqiiqWnGh8Xg2P8mzg"',
#  'items': [{'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/0-ze2anWOfyPO-EEuYJurUB2bcs"',
#    'id': 'lLWEXRAnQd0',
#    'kind': 'youtube#video',
#    'snippet': {'categoryId': '24',
#     'channelId': 'UCxcnsr1R5Ge_fbTu5ajt8DQ',
#     'channelTitle': 'Bob Ross',
#     'defaultAudioLanguage': 'en',
#     'defaultLanguage': 'en',
#     'description': 'Take a walk with Bob Ross down a little lakeside path in a secluded place; you’ll delight in the discovery of a small uninhabited island. \n\nSeason 29 of The Joy of Painting with Bob Ross features the following wonderful painting instructions: island in the Wilderness, Autumn Oval, Seasonal Progression, Light at the Summit, Countryside Barn, Mountain Lake Falls, Cypress Creek, Trapper’s Cabin, Storm on the Horizon, Pot O’ Posies, A Perfect Winter Day, Aurora’s Dance, and Woodman’s Retreat.\n\nSubscribe to the official Bob Ross YouTube channel - http://bit.ly/BobRossSubscribe\n\nSeason 29 Playlist: https://www.youtube.com/playlist?list=PLAEQD0ULngi6c0D5_ELtW5p_NLShDktAN\n\nThe Joy of Painting Season 20 is now on iTunes! - http://bit.ly/iTunesBobRoss\n\nOfficial Bob Ross website - http://www.BobRoss.com\n\nOfficial Bob Ross Twitch.tv Stream! - http://twitch.tv/BobRoss\n\nOfficial Bob Ross Twitter Account - https://twitter.com/bobrossofficial\n\nAll episodes of Bob Ross are now live on Roku - http://bit.ly/BobRossOnRoku\n\nOriginally aired on 8/24/1993',
#     'liveBroadcastContent': 'none',
#     'localized': {'description': 'Take a walk with Bob Ross down a little lakeside path in a secluded place; you’ll delight in the discovery of a small uninhabited island. \n\nSeason 29 of The Joy of Painting with Bob Ross features the following wonderful painting instructions: island in the Wilderness, Autumn Oval, Seasonal Progression, Light at the Summit, Countryside Barn, Mountain Lake Falls, Cypress Creek, Trapper’s Cabin, Storm on the Horizon, Pot O’ Posies, A Perfect Winter Day, Aurora’s Dance, and Woodman’s Retreat.\n\nSubscribe to the official Bob Ross YouTube channel - http://bit.ly/BobRossSubscribe\n\nSeason 29 Playlist: https://www.youtube.com/playlist?list=PLAEQD0ULngi6c0D5_ELtW5p_NLShDktAN\n\nThe Joy of Painting Season 20 is now on iTunes! - http://bit.ly/iTunesBobRoss\n\nOfficial Bob Ross website - http://www.BobRoss.com\n\nOfficial Bob Ross Twitch.tv Stream! - http://twitch.tv/BobRoss\n\nOfficial Bob Ross Twitter Account - https://twitter.com/bobrossofficial\n\nAll episodes of Bob Ross are now live on Roku - http://bit.ly/BobRossOnRoku\n\nOriginally aired on 8/24/1993',
#      'title': 'Bob Ross - Island in the Wilderness (Season 29 Episode 1)'},
#     'publishedAt': '2016-11-28T21:00:02.000Z',
#     'tags': ['steven ross',
#      'bob ross inc',
#      'pastel',
#      'bob ross joy of painting',
#      'drawing',
#      'art',
#      'mountain',
#      'bob ross twitch',
#      'landscape',
#      'bob ross full episode',
#      'oil',
#      'host',
#      'kappaross',
#      'the joy of painting',
#      'coloring',
#      'twitch',
#      'happy trees',
#      'ocean',
#      'stream',
#      'wildlife',
#      'happy accident',
#      'livestream',
#      'bob ross asmr',
#      'paint',
#      'asmr',
#      'full episode',
#      'chill',
#      'free',
#      'pbs',
#      'painting',
#      'bob ross marathon',
#      'lake',
#      'bob ross',
#      'snow',
#      'joy of painting',
#      'happy trails',
#      'bob ross painting',
#      'alaska',
#      'canvas',
#      'tv show',
#      'brushes'],
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/lLWEXRAnQd0/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/lLWEXRAnQd0/hqdefault.jpg',
#       'width': 480},
#      'maxres': {'height': 720,
#       'url': 'https://i.ytimg.com/vi/lLWEXRAnQd0/maxresdefault.jpg',
#       'width': 1280},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/lLWEXRAnQd0/mqdefault.jpg',
#       'width': 320},
#      'standard': {'height': 480,
#       'url': 'https://i.ytimg.com/vi/lLWEXRAnQd0/sddefault.jpg',
#       'width': 640}},
#     'title': 'Bob Ross - Island in the Wilderness (Season 29 Episode 1)'},
#    'statistics': {'commentCount': '21209',
#     'dislikeCount': '2249',
#     'favoriteCount': '0',
#     'likeCount': '152477',
#     'viewCount': '7529170'}}],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %% [markdown]
# This sample entry looks like the relevant information in in ```items```, which is a list with just one entry.  Is that true?

# %%
all(len(js['items']) == 1 for js in json_data)
# Out:
# True

# %% [markdown]
# Define a function to extract parts from the ```items``` list

# %%
def extract_record(js):
    js = js['items'][0]
    record = {}
    record['id'] = js['id']
    record['etag'] = js['etag']
    for stat, value in js['statistics'].items():
        record[stat] = int(value)
    for snippet, value in js['snippet'].items():
        record[snippet] = value
    return record

# %%
records = [extract_record(js) for js in json_data]
record_df = pd.DataFrame.from_records(records)
print("Read %d video records" % len(record_df))
record_df.head(2)
# Out:
# Read 446 video records
#   categoryId                 channelId channelTitle  commentCount  \
# 0         24  UCxcnsr1R5Ge_fbTu5ajt8DQ     Bob Ross          1589
# 1         24  UCxcnsr1R5Ge_fbTu5ajt8DQ     Bob Ross         21209
#
#   defaultAudioLanguage defaultLanguage  \
# 0                   en             NaN
# 1                   en              en
#
#                                          description  dislikeCount  \
# 0  Bundle up with Bob Ross when you visit this to...           311
# 1  Take a walk with Bob Ross down a little lakesi...          2249
#
#                                                 etag  favoriteCount  \
# 0  "DuHzAJ-eQIiCIp7p4ldoVcVAOeY/YgvQsJek2VuEzG0fc...              0
# 1  "DuHzAJ-eQIiCIp7p4ldoVcVAOeY/0-ze2anWOfyPO-EEu...              0
#
#             id  likeCount liveBroadcastContent  \
# 0  TohG7F8M3Ls      14005                 none
# 1  lLWEXRAnQd0     152477                 none
#
#                                            localized  \
# 0  {'title': 'Bob Ross - Glacier Lake (Season 28 ...
# 1  {'title': 'Bob Ross - Island in the Wilderness...
#
#                 publishedAt  \
# 0  2016-11-20T21:00:01.000Z
# 1  2016-11-28T21:00:02.000Z
#
#                                                 tags  \
# 0  [twitch, the joy of painting, asmr, happy trai...
# 1  [steven ross, bob ross inc, pastel, bob ross j...
#
#                                           thumbnails  \
# 0  {'default': {'url': 'https://i.ytimg.com/vi/To...
# 1  {'default': {'url': 'https://i.ytimg.com/vi/lL...
#
#                                                title  viewCount
# 0      Bob Ross - Glacier Lake (Season 28 Episode 6)    1160972
# 1  Bob Ross - Island in the Wilderness (Season 29...    7529170

# %%
record_df_slim = record_df[['title','id', 'viewCount', 'likeCount', 'favoriteCount', 'dislikeCount', 'commentCount']]
df = record_df_slim.set_index('id')
df.head()
# Out:
#                                                          title  viewCount  \
# id
# TohG7F8M3Ls      Bob Ross - Glacier Lake (Season 28 Episode 6)    1160972
# lLWEXRAnQd0  Bob Ross - Island in the Wilderness (Season 29...    7529170
# kJFB6rH3z2A  Bob Ross - Reflections of Calm (Season 31 Epis...    1432050
# kasGRkfkiPM  Bob Ross - Mountain Summit (Season 13 Episode 10)    3041171
# tWoInh2USOs  Bob Ross - Delightful Meadow Home (Season 26 E...     453935
#
#              likeCount  favoriteCount  dislikeCount  commentCount
# id
# TohG7F8M3Ls      14005              0           311          1589
# lLWEXRAnQd0     152477              0          2249         21209
# kJFB6rH3z2A      17979              0           334          2346
# kasGRkfkiPM      22498              0           542          3310
# tWoInh2USOs       3930              0            96           457

# %%
import re
regex = r'^Bob Ross - (?P<episode_title>[A-Za-z0-9 ]+) \(Season (?P<season_num>\d+) Episode (?P<episode_num>\d+)\)'
newcols = df['title'].str.extract(regex)
newcols.head()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   This is separate from the ipykernel package so we can avoid doing imports until
#                         episode_title season_num episode_num
# id
# TohG7F8M3Ls              Glacier Lake         28           6
# lLWEXRAnQd0  Island in the Wilderness         29           1
# kJFB6rH3z2A       Reflections of Calm         31           1
# kasGRkfkiPM           Mountain Summit         13          10
# tWoInh2USOs    Delightful Meadow Home         26           2

# %%
df = pd.concat([df, newcols], axis=1)

# %%
df['episode_title'] = df['episode_title'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-6693aabd341b> in <module>()
# ----> 1 df['episode_title'] = df['episode_title'].str.lower()
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
df
# Out:
#                                                          title  viewCount  \
# id
# TohG7F8M3Ls      Bob Ross - Glacier Lake (Season 28 Episode 6)    1160972
# lLWEXRAnQd0  Bob Ross - Island in the Wilderness (Season 29...    7529170
# kJFB6rH3z2A  Bob Ross - Reflections of Calm (Season 31 Epis...    1432050
# kasGRkfkiPM  Bob Ross - Mountain Summit (Season 13 Episode 10)    3041171
# tWoInh2USOs  Bob Ross - Delightful Meadow Home (Season 26 E...     453935
# UQ-RTZCOQn0      Bob Ross - Arctic Beauty (Season 6 Episode 7)    2947352
# raAkJKeo0Sk        Bob Ross - First Snow (Season 26 Episode 3)     216644
# HCsCatvigtw  Bob Ross - Mountain at Sunset (Season 12 Episo...    1580910
# jyknCVczn3Q                         Bob Ross - Painting Clouds     101521
# qTDQt_PdlYc    Bob Ross - Lonely Retreat (Season 8 Episode 12)    1128324
# qx2IsmrCs3c  Bob Ross - In the Midst of Winter (Season 31 E...    1244488
# UOziR7PoVco       Bob Ross - Ebony Sunset (Season 1 Episode 3)     474678
# L5bXkI0-pEg          Bob Ross - Campfire (Season 3 Episode 10)    2784963
# vrAMRxBB5KI   Bob Ross - Secluded Bridge (Season 10 Episode 4)     542296
# o2cjLA_wgIk  Bob Ross - Mountain Challenge (Season 4 Episod...     408583
# xj8xsTSkbUk       1264              0            34           125
# 3CDg_9gL-5M       1710              0            42           230
# ...                ...            ...           ...           ...
# TQ4AAR8F2m4         12              0             1             1
# OUjvorUjJIQ          5              0             0             1
# 5VDcW6nxXX4         10              0             1             5
# _OlzlNJs_2s         12              0             1             0
# yKm41JXqXp4         36              0             4             0
# 2W7UcgXQp9I         12              0             0             0
# hdAv1ICmjPE         20              0             0             2
# jvmBQGWOSb8        117              0            11             6
# lSk_xwID39o         96              0             1             1
# eHglOflhoxc         11              0             0             0
# J0cnJNIlJUw         54              0             2             3
# 39usF1HDSJc         62              0             1             4
# 5eNfmCkH2_E        103              0             8            14
# 13E_oknlQno         63              0             5             6
# Gz8wVnwCJUA         12              0             0             0
# aIH7_bS2C4c         82              0             8             7
# ApufRnxtBag         12              0             3             1
# z5shjCWzXuE         52              0             2             4
# fhyklXr6JQc         12              0             0             0
# bthdF9HSupU         10              0             0             0
# Gk_-OLC0FZs         11              0             0             0
# livwrYg2LwU          8              0             0             1
# 4m4mRMWmtVY         10              0             0             0
# OoDd3Z6oM-A          7              0             0             0
# tdTuDnMNyrA         22              0             1             1
# IBFeDo9SsAA        198              0            26            14
# qD5IRc3BB-M         22              0             2             8
# KVfjyxA2fME         47              0             3             3
# swyg__B-QJg          4              0             1             0
# dUCN7UTkukM          7              0             0             0
# _8orqS6TGcw          7              0             0             0
# LzH1WqBwjW0          7              0             0             0
# 7yB1-pkEd50         36              0             3             5
# iLiMzMKiKo8          4              0             0             1
# _UUwS2ERDYE         19              0             5             0
# Cve9sbkfV2A          5              0             2             1
# aFiBK0FdlEU         74              0             2             4
# szictM0TP2k          6              0             0             0
# SGIeOSpqC1I         10              0             0             0
# HyjUeINRC4Q          7              0             1             0
# TETRCQiCzM4         12              0             2             5
# riLhZb2cg1c         77              0             7             5
# h4UlacvbbG0          8              0             0             5
# MjD_uu6RPKU         12              0             1             0
# FKImN-7z_Rk         13              0             3             2
# jnoVDejsnK4          5              0             0             1
# lwGuQsJ1pa0         13              0             3             2
# -_tmeu4yKE0          9              0             1             0
# q6GirqhRUfc          9              0             1             0
# pH09snE4tjU          5              0             0             0
#
#                         episode_title season_num episode_num  \
# id
# TohG7F8M3Ls              glacier lake         28           6
# lLWEXRAnQd0  island in the wilderness         29           1
# kJFB6rH3z2A       reflections of calm         31           1
# kasGRkfkiPM           mountain summit         13          10
# tWoInh2USOs    delightful meadow home         26           2
# UQ-RTZCOQn0             arctic beauty          6           7
# raAkJKeo0Sk                first snow         26           3
# HCsCatvigtw        mountain at sunset         12          10
# jyknCVczn3Q                       NaN        NaN         NaN
# qTDQt_PdlYc            lonely retreat          8          12
# qx2IsmrCs3c    in the midst of winter         31          12
# UOziR7PoVco              ebony sunset          1           3
# L5bXkI0-pEg                  campfire          3          10
# vrAMRxBB5KI           secluded bridge         10           4
# o2cjLA_wgIk        mountain challenge          4          13
# zxj3xLDNxo0   golden rays of sunshine         28           4
# vgbMONXc9Cs           northern lights          8          13
# eTEKGOi6SVg                       NaN        NaN         NaN
# RqtDliGeyTg            the footbridge         24          12
# mEU0stNfkxI          evergreen valley         31           9
# zoTeyliLn5o               triple view         10          11
# 4XxClvPZ1RE             gray mountain         24           1
# VnZEpic2UzU                       NaN        NaN         NaN
# x-9CqidKRSM                       NaN        NaN         NaN
# 530_cVmexiI           misty waterfall          7           6
# RInDWhYceLU                       NaN        NaN         NaN
# I-ousb8-SD0            shades of grey          2           4
# 4KYxkqlzyqM                dock scene          7          12
# 1s58rW0_LN4            towering peaks         10           1
# Ov5oIHTAa10     meadow brook surprise         14           2
# aA8RhtaWACA               golden glow         11          11
# gMEZp47VKC0              sunset aglow         26          12
# wrbGlR22K0Q              forest river         27          12
# mUJoNLWQ1yI           warm winter day          8           3
# iRMsb9Vf7GM                       NaN        NaN         NaN
# VlucWfTUo1A           mystic mountain         20           1
# 9BHWlbjd95c      an arctic winter day         26           6
# oh5p5f5_-7A       a walk in the woods          1           1
# PutvF_P4588         evening waterfall         12           8
# y6GVVjG4HMg               windy waves         14           7
# Ugiwi8uizpg                marshlands          6          12
# DqhzxdkdQS0        mountain waterfall          5           1
# wJmi7-G9r-w         barn in snow oval         16           9
# OFKFUJ9eDNs              the old mill          3           9
# RrBsbqO9aqI         tropical seascape         12           9
# 8ysFkNYwhAE              winter night          3           4
# l141Y0x8om0               night light          3           8
# 0pwoixRikn4               winter mist          1           4
# xj8xsTSkbUk              the windmill          5          10
# 3CDg_9gL-5M  little house by the road          9           8
# ...                               ...        ...         ...
# TQ4AAR8F2m4                       NaN        NaN         NaN
# OUjvorUjJIQ                       NaN        NaN         NaN
# 5VDcW6nxXX4                       NaN        NaN         NaN
# _OlzlNJs_2s                       NaN        NaN         NaN
# yKm41JXqXp4                       NaN        NaN         NaN
# 2W7UcgXQp9I                       NaN        NaN         NaN
# hdAv1ICmjPE                       NaN        NaN         NaN
# jvmBQGWOSb8                       NaN        NaN         NaN
# lSk_xwID39o                       NaN        NaN         NaN
# eHglOflhoxc                       NaN        NaN         NaN
# J0cnJNIlJUw                       NaN        NaN         NaN
# 39usF1HDSJc                       NaN        NaN         NaN
# 5eNfmCkH2_E                       NaN        NaN         NaN
# 13E_oknlQno                       NaN        NaN         NaN
# Gz8wVnwCJUA                       NaN        NaN         NaN
# aIH7_bS2C4c                       NaN        NaN         NaN
# ApufRnxtBag                       NaN        NaN         NaN
# z5shjCWzXuE                       NaN        NaN         NaN
# fhyklXr6JQc                       NaN        NaN         NaN
# bthdF9HSupU                       NaN        NaN         NaN
# Gk_-OLC0FZs                       NaN        NaN         NaN
# livwrYg2LwU                       NaN        NaN         NaN
# 4m4mRMWmtVY                       NaN        NaN         NaN
# OoDd3Z6oM-A                       NaN        NaN         NaN
# tdTuDnMNyrA                       NaN        NaN         NaN
# IBFeDo9SsAA                       NaN        NaN         NaN
# qD5IRc3BB-M                       NaN        NaN         NaN
# KVfjyxA2fME                       NaN        NaN         NaN
# swyg__B-QJg                       NaN        NaN         NaN
# dUCN7UTkukM                       NaN        NaN         NaN
# _8orqS6TGcw                       NaN        NaN         NaN
# LzH1WqBwjW0                       NaN        NaN         NaN
# 7yB1-pkEd50                       NaN        NaN         NaN
# iLiMzMKiKo8                       NaN        NaN         NaN
# _UUwS2ERDYE                       NaN        NaN         NaN
# Cve9sbkfV2A                       NaN        NaN         NaN
# aFiBK0FdlEU                       NaN        NaN         NaN
# szictM0TP2k                       NaN        NaN         NaN
# SGIeOSpqC1I                       NaN        NaN         NaN
# HyjUeINRC4Q                       NaN        NaN         NaN
# TETRCQiCzM4                       NaN        NaN         NaN
# riLhZb2cg1c                       NaN        NaN         NaN
# h4UlacvbbG0                       NaN        NaN         NaN
# MjD_uu6RPKU                       NaN        NaN         NaN
# FKImN-7z_Rk                       NaN        NaN         NaN
# jnoVDejsnK4                       NaN        NaN         NaN
# lwGuQsJ1pa0                       NaN        NaN         NaN
# -_tmeu4yKE0                       NaN        NaN         NaN
# q6GirqhRUfc                       NaN        NaN         NaN
# pH09snE4tjU                       NaN        NaN         NaN
#
#                         episode_title season_num episode_num
# id
# TohG7F8M3Ls              Glacier Lake         28           6
# lLWEXRAnQd0  Island in the Wilderness         29           1
# kJFB6rH3z2A       Reflections of Calm         31           1
# kasGRkfkiPM           Mountain Summit         13          10
# tWoInh2USOs    Delightful Meadow Home         26           2
# UQ-RTZCOQn0             Arctic Beauty          6           7
# raAkJKeo0Sk                First Snow         26           3
# HCsCatvigtw        Mountain at Sunset         12          10
# jyknCVczn3Q                       NaN        NaN         NaN
# qTDQt_PdlYc            Lonely Retreat          8          12
# qx2IsmrCs3c    In the Midst of Winter         31          12
# UOziR7PoVco              Ebony Sunset          1           3
# L5bXkI0-pEg                  Campfire          3          10
# vrAMRxBB5KI           Secluded Bridge         10           4
# o2cjLA_wgIk        Mountain Challenge          4          13
# zxj3xLDNxo0   Golden Rays of Sunshine         28           4
# vgbMONXc9Cs           Northern Lights          8          13
# eTEKGOi6SVg                       NaN        NaN         NaN
# RqtDliGeyTg            The Footbridge         24          12
# mEU0stNfkxI          Evergreen Valley         31           9
# zoTeyliLn5o               Triple View         10          11
# 4XxClvPZ1RE             Gray Mountain         24           1
# VnZEpic2UzU                       NaN        NaN         NaN
# x-9CqidKRSM                       NaN        NaN         NaN
# 530_cVmexiI           Misty Waterfall          7           6
# RInDWhYceLU                       NaN        NaN         NaN
# I-ousb8-SD0            Shades of Grey          2           4
# 4KYxkqlzyqM                Dock Scene          7          12
# 1s58rW0_LN4            Towering Peaks         10           1
# Ov5oIHTAa10     Meadow Brook Surprise         14           2
# aA8RhtaWACA               Golden Glow         11          11
# gMEZp47VKC0              Sunset Aglow         26          12
# wrbGlR22K0Q              Forest River         27          12
# mUJoNLWQ1yI           Warm Winter Day          8           3
# iRMsb9Vf7GM                       NaN        NaN         NaN
# VlucWfTUo1A           Mystic Mountain         20           1
# 9BHWlbjd95c      An Arctic Winter Day         26           6
# oh5p5f5_-7A       A Walk in the Woods          1           1
# PutvF_P4588         Evening Waterfall         12           8
# y6GVVjG4HMg               Windy Waves         14           7
# Ugiwi8uizpg                Marshlands          6          12
# DqhzxdkdQS0        Mountain Waterfall          5           1
# wJmi7-G9r-w         Barn in Snow Oval         16           9
# OFKFUJ9eDNs              The Old Mill          3           9
# RrBsbqO9aqI         Tropical Seascape         12           9
# 8ysFkNYwhAE              Winter Night          3           4
# l141Y0x8om0               Night Light          3           8
# 0pwoixRikn4               Winter Mist          1           4
# xj8xsTSkbUk              The Windmill          5          10
# 3CDg_9gL-5M  Little House by the Road          9           8
# ...                               ...        ...         ...
# TQ4AAR8F2m4                       NaN        NaN         NaN
# OUjvorUjJIQ                       NaN        NaN         NaN
# 5VDcW6nxXX4                       NaN        NaN         NaN
# _OlzlNJs_2s                       NaN        NaN         NaN
# yKm41JXqXp4                       NaN        NaN         NaN
# 2W7UcgXQp9I                       NaN        NaN         NaN
# hdAv1ICmjPE                       NaN        NaN         NaN
# jvmBQGWOSb8                       NaN        NaN         NaN
# lSk_xwID39o                       NaN        NaN         NaN
# eHglOflhoxc                       NaN        NaN         NaN
# J0cnJNIlJUw                       NaN        NaN         NaN
# 39usF1HDSJc                       NaN        NaN         NaN
# 5eNfmCkH2_E                       NaN        NaN         NaN
# 13E_oknlQno                       NaN        NaN         NaN
# Gz8wVnwCJUA                       NaN        NaN         NaN
# aIH7_bS2C4c                       NaN        NaN         NaN
# ApufRnxtBag                       NaN        NaN         NaN
# z5shjCWzXuE                       NaN        NaN         NaN
# fhyklXr6JQc                       NaN        NaN         NaN
# bthdF9HSupU                       NaN        NaN         NaN
# Gk_-OLC0FZs                       NaN        NaN         NaN
# livwrYg2LwU                       NaN        NaN         NaN
# 4m4mRMWmtVY                       NaN        NaN         NaN
# OoDd3Z6oM-A                       NaN        NaN         NaN
# tdTuDnMNyrA                       NaN        NaN         NaN
# IBFeDo9SsAA                       NaN        NaN         NaN
# qD5IRc3BB-M                       NaN        NaN         NaN
# KVfjyxA2fME                       NaN        NaN         NaN
# swyg__B-QJg                       NaN        NaN         NaN
# dUCN7UTkukM                       NaN        NaN         NaN
# _8orqS6TGcw                       NaN        NaN         NaN
# LzH1WqBwjW0                       NaN        NaN         NaN
# 7yB1-pkEd50                       NaN        NaN         NaN
# iLiMzMKiKo8                       NaN        NaN         NaN
# _UUwS2ERDYE                       NaN        NaN         NaN
# Cve9sbkfV2A                       NaN        NaN         NaN
# aFiBK0FdlEU                       NaN        NaN         NaN
# szictM0TP2k                       NaN        NaN         NaN
# SGIeOSpqC1I                       NaN        NaN         NaN
# HyjUeINRC4Q                       NaN        NaN         NaN
# TETRCQiCzM4                       NaN        NaN         NaN
# riLhZb2cg1c                       NaN        NaN         NaN
# h4UlacvbbG0                       NaN        NaN         NaN
# MjD_uu6RPKU                       NaN        NaN         NaN
# FKImN-7z_Rk                       NaN        NaN         NaN
# jnoVDejsnK4                       NaN        NaN         NaN
# lwGuQsJ1pa0                       NaN        NaN         NaN
# -_tmeu4yKE0                       NaN        NaN         NaN
# q6GirqhRUfc                       NaN        NaN         NaN
# pH09snE4tjU                       NaN        NaN         NaN
#
# [446 rows x 12 columns]

# %%
df.to_csv('../data/video_stats2.csv')
